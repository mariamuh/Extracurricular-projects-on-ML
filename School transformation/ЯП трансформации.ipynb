# %%
# подключим диск
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# импортируем необходимые библиотеки
import numpy as np
import pandas as pd
import nltk
from sklearn import feature_extraction

from nltk.tokenize import word_tokenize
# from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer

# %%
data = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/ЯП трансформации/q32.xlsx',
                     header=None, 
                     names=['rid', 'sid', 'theme_1', 'theme_2'],
                     skiprows=3, na_filter='')

# %%
data.head()
# Out:
#      rid    sid                                            theme_1 theme_2
# 0  29819  35292                                                МЭШ
# 1  29854  35039
# 2  29825  35292                                         Технологии   успех
# 3  29826  35100
# 4  29866  35044  Цифровая трансформация образовательной деятель...

# %%
data.shape[0]
# Out:
# 14954

# %% [markdown]
# Приведем таблицу к удобному для работы виду, для этого нам нужно:
#
# 1. сконкатенировать колонки theme_1 и theme_2
# 2. очистить текст от спецсимволов и знаков препинания
#
#   (!) можно провести замену сокращений (например, ИП – индивидуальный         предприниматель),
#
#   (!) можно также удалить самые частые слова
#
# 3. перевести все слова в нижний регистр, провести стемминг/лемматизация
# 4. провести токинезацию
# 5. убрать строки с пустыми значениями
# 6. после провести векторизацию (bag of words)
# 7. не забыть про нормализацию
# 8. (!) можно так же попробовать создать вручную словарь с самыми частыми словами (МЭШ, успех, цифровизация, ...), затем сопоставить этим частым словам классы и назначить соответствующие классы соответствующим учительским оценкам, а остатки разбить на оставшееся кол-во классов

# %%
# сконкатенируем theme_1 и theme_2
data['theme'] = data['theme_1'].astype(str) + ' ' + data['theme_2'].astype(str)
data.head()
# Out:
#      rid    sid                                            theme_1 theme_2  \
# 0  29819  35292                                                МЭШ
# 1  29854  35039
# 2  29825  35292                                         Технологии   успех
# 3  29826  35100
# 4  29866  35044  Цифровая трансформация образовательной деятель...
#
#                                                theme
# 0                                               МЭШ
# 1
# 2                                   Технологии успех
# 3
# 4  Цифровая трансформация образовательной деятель...

# %%
data.shape[0]
# Out:
# 14954

# %%
# очистим текст от спецсимволов и знаков препинания
from string import punctuation

data['theme'] = data['theme'].apply(lambda x: x.translate(str.maketrans('', '', punctuation)))

# %%
data.shape[0]
# Out:
# 14954

# %%
# проведем стемминг, при этом приведем все слова к нижнему регистру 
stemmer = SnowballStemmer('russian')

def MyTokenizer(themes):
    #ads = list(map(str.lower, ads)) # в случае списка строк, но здесь это не нужно
    
    themes_tokenized = [' '.join([stemmer.stem(w) for w in word_tokenize(theme.lower()) if w.isalpha()]) for theme in themes]
    return themes_tokenized

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
data['theme'] = MyTokenizer(data['theme'])

# %%
data.shape[0]
# Out:
# 14954

# %%
# уберем строки с пустыми значениями 
# data = data[data['theme'] != ''] 

data['theme'].replace('', np.nan, inplace=True)
data.dropna(subset=['theme'], inplace=True)

# %%
data.head()
# Out:
#      rid    sid                                            theme_1 theme_2  \
# 0  29819  35292                                                МЭШ
# 2  29825  35292                                         Технологии   успех
# 4  29866  35044  Цифровая трансформация образовательной деятель...
# 5  29879  34977                                          сберкласс
# 6  29888  34661            Информационные технологии в рамках ФГОС
#
#                                        theme
# 0                                        мэш
# 2                             технолог успех
# 4  цифров трансформац образовательн деятельн
# 5                                  сберкласс
# 6           информацион технолог в рамк фгос

# %%
data.shape[0]
# Out:
# 9424

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer 

tfidf_vectorizer = TfidfVectorizer()
# bag of words
bow = tfidf_vectorizer.fit_transform(data['theme'])

# %%
bow
# Out:
# <9424x2295 sparse matrix of type '<class 'numpy.float64'>'
# 	with 39476 stored elements in Compressed Sparse Row format>

# %%
# scaler500_2 = MaxAbsScaler()
# bow500_2 = scaler500_2.fit_transform(bow500_2)

# %% [markdown]
# Мы привели отзывы учителей к виду, приемлемому для обучения моделей. Построим первую модель кластеризации. Будем использовать для этого метод k-средних:

# %%
num_clusters = 10

# Метод k-средних - KMeans
from sklearn.cluster import KMeans

km = KMeans( n_clusters=num_clusters)
idx = km.fit(bow)

# %%
clusters = km.labels_.tolist() 

# print(clusters) 
# print(km.labels_)

# %%
len(clusters)
# Out:
# 9424

# %%
data['cluster'] = pd.DataFrame(clusters)

# кластеры от 1 до 10
data['cluster'] += 1
data['cluster'] = data['cluster'].apply(lambda x: str(x)[0:-2])

# %%
data[~data['cluster'].astype(bool)].shape[0]
# Out:
# 0

# %%
data.head()
# Out:
#      rid    sid                                            theme_1 theme_2  \
# 0  29819  35292                                                МЭШ
# 2  29825  35292                                         Технологии   успех
# 4  29866  35044  Цифровая трансформация образовательной деятель...
# 5  29879  34977                                          сберкласс
# 6  29888  34661            Информационные технологии в рамках ФГОС
#
#                                        theme cluster
# 0                                        мэш       9
# 2                             технолог успех       7
# 4  цифров трансформац образовательн деятельн       1
# 5                                  сберкласс       5
# 6           информацион технолог в рамк фгос       4

# %%
data.shape[0]
# Out:
# 9424

# %%
from sklearn.cluster import DBSCAN 

db = DBSCAN(eps=0.5, min_samples=70).fit(bow)
labels = db.labels_

# %%
data['cluster_2'] = pd.DataFrame(labels)
data['cluster_2'] += 2
data['cluster_2'] = data['cluster_2'].apply(lambda x: str(x)[0:-2])

# %%
data.head(50)
# Out:
#       rid    sid                                            theme_1  \
# 0   29819  35292                                                МЭШ
# 2   29825  35292                                         Технологии
# 4   29866  35044  Цифровая трансформация образовательной деятель...
# 5   29879  34977                                          сберкласс
# 6   29888  34661            Информационные технологии в рамках ФГОС
# 7   29867  34977                               Цифровая грамотность
# 8   29886  34977  Обучение Персонализированной системе образован...
# 9   29953  35112  Методология и технология дистанционного обучен...
# 11  29899  35292                             "Школа цифрового века"
# 12  29868  34977                  Подготовка к итоговой аттестации.
# 14  30360  35196                                       Работа с эжд
# 15  30196  35196        Современные технологии на уроках математики
# 16  30004  35196                                      Робототехника
# 19  30164  35196                              Обучение работе с МЭШ
# 20  30042  35196                                                ЕГЭ
# 25  30133  35196  «Создание электронных образовательных материал...
# 26  30978  34860                                               Кеен
# 28  30192  34775             Цифровые технологии в учебном процессе
# 29  30991  35112  Внедрение целевой модели цифровой образователь...
# 30  30014  35196                   Курсы по использованию доски МЭШ
# 31  29897  35292             Дистанционные технологии в образовании
# 32  30998  34860                        Информационная граммотность
# 33  30821  35292                                                Мэш
# 35  29964  35196                              Ведение уроков онлайн
# 40  29898  35292               Информационные технологии в обучении
# 41  30023  35196                                                МЭШ
# 42  31510  35112  Безопасное использование сайтов в сети "Интерн...
# 43  31646  35031  Современные информационно-коммуникационные и ц...
# 44  31786  35292  Сервис ZOOM для организации и проведения диста...
# 46  30817  35292                                                МЭШ
# 47  31431  35015  Информационно-коммуникационные технологии в пр...
# 50  31729  35292           Использование МЭШ в учебной деятельности
# 55  30214  34775                         Цифровые модели и двойники
# 56  31738  35292                                       Работа в МЭШ
# 58  31481  35015                                 цифровые инновации
# 60  30861  34704                                Цифровые технологии
# 64  29890  35292                                  Использование МЭШ
# 66  30016  35196  «Технологии дистанционного обучения с использо...
# 67  30776  35291                                       Работа в МЭШ
# 68  29885  34977                                                ПМО
# 69  31209  35291                                                 Ит
# 71  31228  35291    работа в Тимс, Зум, использование МЭШ на уроках
# 74  31748  35292                                       Работа в МЭШ
# 75  30692  34765                     Цифровая трансформация учителя
# 76  30809  34704  Цифровые технологии в преподавании русского яз...
# 81  31744  35292                            Создание сценарий в МЭШ
# 82  32195  35257             Дистанционное обучение на уроке физики
# 83  31851  35309                                            AutoCad
# 84  30280  35196                                       Работа в ЭЖД
# 85  32190  35257                       Современные технологии урока
#
#                                  theme_2  \
# 0
# 2                                  успех
# 4
# 5
# 6
# 7
# 8
# 9
# 11
# 12  Особенности преподавания математики.
# 14
# 15
# 16
# 19
# 20
# 25
# 26
# 28
# 29
# 30
# 31
# 32
# 33
# 35
# 40
# 41
# 42
# 43
# 44
# 46
# 47
# 50
# 55
# 56
# 58
# 60
# 64
# 66
# 67
# 68
# 69
# 71
# 74
# 75
# 76
# 81
# 82
# 83
# 84
# 85
#
#                                                 theme cluster cluster_2
# 0                                                 мэш       9         2
# 2                                      технолог успех       7         1
# 4           цифров трансформац образовательн деятельн       1         1
# 5                                           сберкласс       5         3
# 6                    информацион технолог в рамк фгос       4         1
# 7                                      цифров грамотн       6         1
# 8   обучен персонализирова систем образован сберкласс       4         1
# 9   методолог и технолог дистанцион обучен в образ...       4         1
# 11                                    школ цифров век      10         1
# 12  подготовк к итогов аттестац особен преподаван ...       4         1
# 14                                        работ с эжд       4         1
# 15                современ технолог на урок математик       4         1
# 16                                       робототехник       4         1
# 19                                 обучен работ с мэш       4         1
# 20                                                егэ       6         1
# 25  создан электрон образовательн материал и их ис...       9         2
# 26                                                 ке       4         1
# 28                    цифров технолог в учебн процесс       4         1
# 29  внедрен целев модел цифров образовательн сред ...       9         2
# 30                       курс по использован доск мэш       4         1
# 31                    дистанцион технолог в образован       4         1
# 32                               информацион граммотн       4         1
# 33                                                мэш       3         2
# 35                                  веден урок онлайн       1         4
# 40                      информацион технолог в обучен       4         1
# 41                                                мэш      10         1
# 42  безопасн использован сайт в сет интернет в обр...       3         2
# 43  современ информационнокоммуникацион и цифров т...       4         1
# 44  сервис zo для организац и проведен дистанцион ...       4         1
# 46                                                мэш       6         1
# 47  информационнокоммуникацион технолог в професси...       4         1
# 50                   использован мэш в учебн деятельн       8         5
# 55                             цифров модел и двойник      10         1
# 56                                        работ в мэш      10         1
# 58                                     цифров инновац       4         1
# 60                                    цифров технолог       4         1
# 64                                    использован мэш       4         1
# 66  технолог дистанцион обучен с использован образ...       3         1
# 67                                        работ в мэш       4         1
# 68                                                пмо       6         1
# 69                                                 ит       4         1
# 71           работ в тимс зум использован мэш на урок       4         1
# 74                                        работ в мэш       4         1
# 75                          цифров трансформац учител       4         1
# 76  цифров технолог в преподаван русск язык и лите...       2         1
# 81                                создан сценар в мэш       3         2
# 82                    дистанцион обучен на урок физик       3         1
# 83                                            autocad       4         1
# 84                                        работ в эжд       9         2
# 85                             современ технолог урок       9         1

# %%
from sklearn.cluster import AgglomerativeClustering 

aggclus = AgglomerativeClustering(n_clusters=num_clusters, affinity='euclidean') #affinity можно выбрать любое или попробовать все по очереди: cosine, l1, l2, manhattan
marks = aggclus.fit_predict(bow.toarray())

# %%
data['cluster_3'] = pd.DataFrame(marks)
data['cluster_3'] += 1
data['cluster_3'] = data['cluster_3'].apply(lambda x: str(x)[0:-2])

# %%
data.head()
# Out:
#      rid    sid                                            theme_1 theme_2  \
# 0  29819  35292                                                МЭШ
# 2  29825  35292                                         Технологии   успех
# 4  29866  35044  Цифровая трансформация образовательной деятель...
# 5  29879  34977                                          сберкласс
# 6  29888  34661            Информационные технологии в рамках ФГОС
#
#                                        theme cluster cluster_2 cluster_3
# 0                                        мэш       9         2         5
# 2                             технолог успех       7         1         1
# 4  цифров трансформац образовательн деятельн       1         1         1
# 5                                  сберкласс       5         3         3
# 6           информацион технолог в рамк фгос       4         1         1

# %%
data.to_excel("results.xlsx")

# %% [markdown]
# Попробуем другой подход.
#
# Выдвинем следующую гипотезу: тезисы учителей о школах так или иначе соотносятся с экспертными оценками этих школ, т.е. не может быть ситуации, при которой учитель высказался плохо о школе, на примерно 2-3 из 10, в то время как эксперт дал оценку 8-9 из 10, с учетом его опыта и знания стратегии выставления оценок, другими словами, учитель может дать приблизительно верную оценку о школе на основе своего опыта работы в ней, эксперт же дает свою также корректную оценку на основе знания своего дела. Таким образом, мы можем сделать вывод о том, что оценки экспертов и учителей должны так или иначе откликаться и не отличаться сильно друг от друга.
#
# Оираясь на данную гипотезу, попробуем использовать экспертные оценки (в числовом виде) школ как вектор правильных ответов для обучения модели.

# %%
# создадим новый датафрейм, но уже с экспертными оценками школ
experts = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/ЯП трансформации/экспертные оценки.xlsx',
                     header=None, 
                     names=['rid', 'sid', 'mark_1', 'mark_2', 'overall_mark'],
                     skiprows=2)

# уберем строки со значениями 99
experts = experts[experts['overall_mark'] != 99] 

# оставим только нужные столбцы
experts = experts[['sid', 'overall_mark']]

# %%
data.head(3)
# Out:
#      rid    sid                                            theme_1 theme_2  \
# 0  29819  35292                                                МЭШ
# 2  29825  35292                                         Технологии   успех
# 4  29866  35044  Цифровая трансформация образовательной деятель...
#
#                                        theme
# 0                                        мэш
# 2                             технолог успех
# 4  цифров трансформац образовательн деятельн

# %%
data = data.merge(experts, how='left', on='sid')

# %%
data.head(3)
# Out:
#      rid    sid                                            theme_1 theme_2  \
# 0  29819  35292                                                МЭШ
# 1  29825  35292                                         Технологии   успех
# 2  29866  35044  Цифровая трансформация образовательной деятель...
#
#                                        theme  overall_mark
# 0                                        мэш           NaN
# 1                             технолог успех           NaN
# 2  цифров трансформац образовательн деятельн           NaN

# %%
# разобъем на обучающую (для которой есть ответы) и тестовую выборки
train_data = data[data['overall_mark'].isnull() == False]
test_data = data[data['overall_mark'].isnull() == True]

# %%
train_data.shape[0] + test_data.shape[0]
# Out:
# 9424

# %%
train_data.head()
# Out:
#       rid    sid                                            theme_1 theme_2  \
# 4   29888  34661            Информационные технологии в рамках ФГОС
# 7   29953  35112  Методология и технология дистанционного обучен...
# 17  30192  34775             Цифровые технологии в учебном процессе
# 18  30991  35112  Внедрение целевой модели цифровой образователь...
# 26  31510  35112  Безопасное использование сайтов в сети "Интерн...
#
#                                                 theme  overall_mark
# 4                    информацион технолог в рамк фгос           4.0
# 7   методолог и технолог дистанцион обучен в образ...           4.0
# 17                    цифров технолог в учебн процесс           7.0
# 18  внедрен целев модел цифров образовательн сред ...           4.0
# 26  безопасн использован сайт в сет интернет в обр...           4.0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

tfidf_vectorizer = TfidfVectorizer()
bow = tfidf_vectorizer.fit_transform(train_data['theme'])

# %%
from sklearn.preprocessing import MaxAbsScaler

scaler = MaxAbsScaler()
bow = scaler.fit_transform(bow)

# %%
from sklearn.linear_model import SGDClassifier 
from sklearn.metrics import accuracy_score 

# обучим SGDClassifier на полученной выборке
clf = SGDClassifier(max_iter=200, random_state=42)
clf.fit(bow, train_data['overall_mark'])
# Out:
# SGDClassifier(max_iter=200, random_state=42)

# %%
test_bow = tfidf_vectorizer.transform(test_data['theme'])

# %%
predictions = clf.predict(test_bow)

# %%
test_data['overall_mark'] = predictions
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
test_data.head(25)
# Out:
#       rid    sid                                            theme_1  \
# 0   29819  35292                                                МЭШ
# 1   29825  35292                                         Технологии
# 2   29866  35044  Цифровая трансформация образовательной деятель...
# 3   29879  34977                                          сберкласс
# 5   29867  34977                               Цифровая грамотность
# 6   29886  34977  Обучение Персонализированной системе образован...
# 8   29899  35292                             "Школа цифрового века"
# 9   29868  34977                  Подготовка к итоговой аттестации.
# 10  30360  35196                                       Работа с эжд
# 11  30196  35196        Современные технологии на уроках математики
# 12  30004  35196                                      Робототехника
# 13  30164  35196                              Обучение работе с МЭШ
# 14  30042  35196                                                ЕГЭ
# 15  30133  35196  «Создание электронных образовательных материал...
# 16  30978  34860                                               Кеен
# 19  30014  35196                   Курсы по использованию доски МЭШ
# 20  29897  35292             Дистанционные технологии в образовании
# 21  30998  34860                        Информационная граммотность
# 22  30821  35292                                                Мэш
# 23  29964  35196                              Ведение уроков онлайн
# 24  29898  35292               Информационные технологии в обучении
# 25  30023  35196                                                МЭШ
# 28  31786  35292  Сервис ZOOM для организации и проведения диста...
# 29  30817  35292                                                МЭШ
# 30  31431  35015  Информационно-коммуникационные технологии в пр...
#
#                                  theme_2  \
# 0
# 1                                  успех
# 2
# 3
# 5
# 6
# 8
# 9   Особенности преподавания математики.
# 10
# 11
# 12
# 13
# 14
# 15
# 16
# 19
# 20
# 21
# 22
# 23
# 24
# 25
# 28
# 29
# 30
#
#                                                 theme  overall_mark
# 0                                                 мэш           7.0
# 1                                      технолог успех           8.0
# 2           цифров трансформац образовательн деятельн           7.0
# 3                                           сберкласс           6.0
# 5                                      цифров грамотн          10.0
# 6   обучен персонализирова систем образован сберкласс           6.0
# 8                                     школ цифров век           9.0
# 9   подготовк к итогов аттестац особен преподаван ...           4.0
# 10                                        работ с эжд           9.0
# 11                современ технолог на урок математик           6.0
# 12                                       робототехник           8.0
# 13                                 обучен работ с мэш           7.0
# 14                                                егэ           8.0
# 15  создан электрон образовательн материал и их ис...           2.0
# 16                                                 ке           6.0
# 19                       курс по использован доск мэш           2.0
# 20                    дистанцион технолог в образован           8.0
# 21                               информацион граммотн          10.0
# 22                                                мэш           7.0
# 23                                  веден урок онлайн           7.0
# 24                      информацион технолог в обучен           7.0
# 25                                                мэш           7.0
# 28  сервис zo для организац и проведен дистанцион ...           2.0
# 29                                                мэш           7.0
# 30  информационнокоммуникацион технолог в професси...           7.0

# %%
results_exp = pd.concat([train_data, test_data], ignore_index=True) 
results_exp['overall_mark'] = results_exp['overall_mark'].apply(lambda x: str(x)[0:-2])
results_exp['overall_mark'] = results_exp['overall_mark'].apply(lambda x: int(x))

# %%
results_exp
# Out:
#         rid    sid                                            theme_1 theme_2  \
# 0     29888  34661            Информационные технологии в рамках ФГОС
# 1     29953  35112  Методология и технология дистанционного обучен...
# 2     30192  34775             Цифровые технологии в учебном процессе
# 3     30991  35112  Внедрение целевой модели цифровой образователь...
# 4     31510  35112  Безопасное использование сайтов в сети "Интерн...
# ...     ...    ...                                                ...     ...
# 9419  76866  34722  использования цифровых технологий в условиях к...
# 9420  60966  35271                                       Работа в МЭШ
# 9421  75493  34664          использование электронной доски на уроках
# 9422  89623  34976  курсы учителей английского языка с использован...
# 9423  89611  34976                        Информационная безопасность
#
#                                                   theme  overall_mark
# 0                      информацион технолог в рамк фгос             4
# 1     методолог и технолог дистанцион обучен в образ...             4
# 2                       цифров технолог в учебн процесс             7
# 3     внедрен целев модел цифров образовательн сред ...             4
# 4     безопасн использован сайт в сет интернет в обр...             4
# ...                                                 ...           ...
# 9419                использован цифров технолог в услов             5
# 9420                                        работ в мэш             7
# 9421                  использован электрон доск на урок             5
# 9422  курс учител английск язык с использован дистан...             8
# 9423                               информацион безопасн            10
#
# [9424 rows x 6 columns]

# %%
results_exp.to_excel("results_exp.xlsx")

# %%
test_data
# Out:
#         rid    sid                                            theme_1 theme_2  \
# 0     29819  35292                                                МЭШ
# 1     29825  35292                                         Технологии   успех
# 2     29866  35044  Цифровая трансформация образовательной деятель...
# 3     29879  34977                                          сберкласс
# 5     29867  34977                               Цифровая грамотность
# ...     ...    ...                                                ...     ...
# 9414  76866  34722  использования цифровых технологий в условиях к...
# 9416  60966  35271                                       Работа в МЭШ
# 9417  75493  34664          использование электронной доски на уроках
# 9419  89623  34976  курсы учителей английского языка с использован...
# 9420  89611  34976                        Информационная безопасность
#
#                                                   theme  overall_mark
# 0                                                   мэш           7.0
# 1                                        технолог успех           8.0
# 2             цифров трансформац образовательн деятельн           7.0
# 3                                             сберкласс           6.0
# 5                                        цифров грамотн          10.0
# ...                                                 ...           ...
# 9414                использован цифров технолог в услов           5.0
# 9416                                        работ в мэш           7.0
# 9417                  использован электрон доск на урок           5.0
# 9419  курс учител английск язык с использован дистан...           8.0
# 9420                               информацион безопасн          10.0
#
# [7118 rows x 6 columns]

# %% [markdown]
# Попробуем перейти к 4-уровневой качественной шкале оценивания:
# - 1-2 = 1
# - 3-5 = 2
# -	6-8 = 3
# -	9-10 = 4

# %%
experts.head()
# Out:
#      sid  overall_mark
# 0  34886             3
# 1  35038             2
# 2  35039             2
# 3  34887             3
# 4  34811             8

# %%
# подгрузим изначальные файлы data и experts 

# experts.loc[:, 'overall_mark'][experts['overall_mark'] < 4] = 1
# experts.loc[:, 'overall_mark'][(experts['overall_mark'] >= 4) & (experts['overall_mark'] <= 5)]['overall_mark'] = 2
# experts.loc[:, 'overall_mark'][(experts['overall_mark'] >= 6) & (experts['overall_mark'] <= 7)]['overall_mark'] = 3
# experts.loc[:, 'overall_mark'][experts['overall_mark'] > 7]['overall_mark'] = 4

def scaling(x):
  if x < 3:
    x = 1
  elif (x >= 3) & (x <= 5):
    x = 2
  elif (x >= 6) & (x <= 8):
    x = 3
  else:
    x = 4
  return x

# переведем в 4-градационную шкалу
experts['overall_mark'] = experts['overall_mark'].apply(scaling)

experts.head()
# Out:
#      sid  overall_mark
# 0  34886             2
# 1  35038             1
# 2  35039             1
# 3  34887             2
# 4  34811             3

# %%
experts['overall_mark'].value_counts()
# Out:
# 3    65
# 2    53
# 1    17
# 4    15
# Name: overall_mark, dtype: int64

# %%
data = data.merge(experts, how='left', on='sid')

# %%
# теперь проделаем все те же самые действия

# from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
# from sklearn.preprocessing import MaxAbsScaler
# from sklearn.linear_model import SGDClassifier
# from sklearn.metrics import accuracy_score 

train_data = data[data['overall_mark'].isnull() == False]
test_data = data[data['overall_mark'].isnull() == True]


tfidf_vectorizer = TfidfVectorizer()
bow = tfidf_vectorizer.fit_transform(train_data['theme'])


scaler = MaxAbsScaler()
bow = scaler.fit_transform(bow)


# обучим SGDClassifier на полученной выборке
clf = SGDClassifier(max_iter=200, random_state=42)
clf.fit(bow, train_data['overall_mark'])

test_bow = tfidf_vectorizer.transform(test_data['theme'])

predictions = clf.predict(test_bow)
test_data['overall_mark'] = predictions

results_exp_with_4_dim = pd.concat([train_data, test_data], ignore_index=True) 
results_exp_with_4_dim['overall_mark'] = results_exp_with_4_dim['overall_mark'].apply(lambda x: str(x)[0:-2])
results_exp_with_4_dim['overall_mark'] = results_exp_with_4_dim['overall_mark'].apply(lambda x: int(x))

results_exp_with_4_dim.to_excel("results_exp_with_4_dim.xlsx")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
results_exp_with_4_dim
# Out:
#         rid    sid                                            theme_1 theme_2  \
# 0     29888  34661            Информационные технологии в рамках ФГОС
# 1     29953  35112  Методология и технология дистанционного обучен...
# 2     30192  34775             Цифровые технологии в учебном процессе
# 3     30991  35112  Внедрение целевой модели цифровой образователь...
# 4     31510  35112  Безопасное использование сайтов в сети "Интерн...
# ...     ...    ...                                                ...     ...
# 9419  76866  34722  использования цифровых технологий в условиях к...
# 9420  60966  35271                                       Работа в МЭШ
# 9421  75493  34664          использование электронной доски на уроках
# 9422  89623  34976  курсы учителей английского языка с использован...
# 9423  89611  34976                        Информационная безопасность
#
#                                                   theme  overall_mark
# 0                      информацион технолог в рамк фгос             2
# 1     методолог и технолог дистанцион обучен в образ...             2
# 2                       цифров технолог в учебн процесс             3
# 3     внедрен целев модел цифров образовательн сред ...             2
# 4     безопасн использован сайт в сет интернет в обр...             2
# ...                                                 ...           ...
# 9419                использован цифров технолог в услов             3
# 9420                                        работ в мэш             3
# 9421                  использован электрон доск на урок             3
# 9422  курс учител английск язык с использован дистан...             3
# 9423                               информацион безопасн             2
#
# [9424 rows x 6 columns]

# %% [markdown]
# Теперь попробуем убрать из обучающей выборки все московские школы, так как их большинство и они могут мешать обучению модели.

# %%
# подгрузим изначальный файл experts, а также файл data_with_regions, где помимо привычных столбцов будет столбец с регионом школы 

# from string import punctuation

data_with_regions = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/ЯП трансформации/q32_with_regions.xlsx',
                     header=None, 
                     names=['rid', 'sid', 'reg', 'theme_1', 'theme_2'],
                     skiprows=3, na_filter='')

# сконкатенируем theme_1 и theme_2
data_with_regions['theme'] = data_with_regions['theme_1'].astype(str) + ' ' + data_with_regions['theme_2'].astype(str)

# очистим текст от спецсимволов и знаков препинания
data_with_regions['theme'] = data_with_regions['theme'].apply(lambda x: x.translate(str.maketrans('', '', punctuation)))

# проведем стемминг, при этом приведем все слова к нижнему регистру 
data_with_regions['theme'] = MyTokenizer(data_with_regions['theme'])

# уберем строки с пустыми значениями
data_with_regions['theme'].replace('', np.nan, inplace=True)
data_with_regions.dropna(subset=['theme'], inplace=True)

# %%
data_with_regions.head()
# Out:
#      rid    sid  reg                                            theme_1  \
# 0  29819  35292   12                                                МЭШ
# 2  29825  35292   12                                         Технологии
# 4  29866  35044   45  Цифровая трансформация образовательной деятель...
# 5  29879  34977   46                                          сберкласс
# 6  29888  34661   22            Информационные технологии в рамках ФГОС
#
#   theme_2                                      theme
# 0                                                мэш
# 2   успех                             технолог успех
# 4          цифров трансформац образовательн деятельн
# 5                                          сберкласс
# 6                   информацион технолог в рамк фгос

# %%
# проделаем те же действия, но теперь все школы московского региона переместим в тестовую выборку

data_with_regions = data_with_regions.merge(experts, how='left', on='sid')

# разобъем объекты на обучающую и тестовую выборки таким образом, чтобы все московские школы оказались в тестовой выборке
train_data = data_with_regions[(data_with_regions['overall_mark'].isnull() == False) & (data_with_regions['reg'] != 12)]
test_data = data_with_regions[(data_with_regions['overall_mark'].isnull() == True) |
                              ((data_with_regions['overall_mark'].isnull() == False) & (data_with_regions['reg'] == 12))]


tfidf_vectorizer = TfidfVectorizer()
bow = tfidf_vectorizer.fit_transform(train_data['theme'])


scaler = MaxAbsScaler()
bow = scaler.fit_transform(bow)


# обучим SGDClassifier на полученной выборке
clf = SGDClassifier(max_iter=200, random_state=42)
clf.fit(bow, train_data['overall_mark'])

test_bow = tfidf_vectorizer.transform(test_data['theme'])

predictions = clf.predict(test_bow)
test_data['overall_mark'] = predictions

results_exp_separately_moscow = pd.concat([train_data, test_data], ignore_index=True) 
results_exp_separately_moscow['overall_mark'] = results_exp_separately_moscow['overall_mark'].apply(lambda x: str(x)[0:-2])
results_exp_separately_moscow['overall_mark'] = results_exp_separately_moscow['overall_mark'].apply(lambda x: int(x))

results_exp_separately_moscow.to_excel("results_exp_separately_moscow.xlsx")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Попробуем убрать из обучающей выборки не все московские школы, а только какую-то их часть.

# %%
data_with_regions['reg'].value_counts()
# Out:
# 12     4127
# 23      677
# 11      235
# 45      209
# 100     202
#        ...
# 433      11
# 72       11
# 57        7
# 62        7
# 48        4
# Name: reg, Length: 84, dtype: int64

# %%
# подгрузим изначальные файлы expertsи и data_with_regions и 
# проделаем те же действия, но теперь часть школ московского региона оставим в обучающей выборке, а
# часть - переместим в тестовую выборку

# from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
# from sklearn.preprocessing import MaxAbsScaler
# from sklearn.linear_model import SGDClassifier
# from sklearn.metrics import accuracy_score 

data_with_regions = data_with_regions.merge(experts, how='left', on='sid')

# возьмем рандомные 700 индексов строк с московскими школами
inxs = np.random.choice(np.array(data_with_regions[data_with_regions['reg'] == 12].index), 700)

train_data = data_with_regions[(data_with_regions['overall_mark'].isnull() == False) & 
                               ((data_with_regions['reg'] != 12) | (data_with_regions.index.isin(inxs)))]
test_data = data_with_regions[(data_with_regions['overall_mark'].isnull() == True) |
                              ((data_with_regions['overall_mark'].isnull() == False) & (data_with_regions['reg'] == 12))]


tfidf_vectorizer = TfidfVectorizer()
bow = tfidf_vectorizer.fit_transform(train_data['theme'])


scaler = MaxAbsScaler()
bow = scaler.fit_transform(bow)


# обучим SGDClassifier на полученной выборке
clf = SGDClassifier(max_iter=200, random_state=42)
clf.fit(bow, train_data['overall_mark'])

test_bow = tfidf_vectorizer.transform(test_data['theme'])

predictions = clf.predict(test_bow)
test_data['overall_mark'] = predictions

results_exp_700_moscow_in_train = pd.concat([train_data, test_data], ignore_index=True) 
results_exp_700_moscow_in_train['overall_mark'] = results_exp_700_moscow_in_train['overall_mark'].apply(lambda x: str(x)[0:-2])
results_exp_700_moscow_in_train['overall_mark'] = results_exp_700_moscow_in_train['overall_mark'].apply(lambda x: int(x))

results_exp_700_moscow_in_train.to_excel("results_exp_700_moscow_in_train.xlsx")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
